# %%
#This a basic project of Python (smart calculator)
responses=["Welcome user","My name is smarty","Thanks","Sorry,This is beyond my ability",
           "How can i help you in normal mathematcal calculation","Hlw","Mentoned not its my work"]
def extract_number_from_text(text):
    l=[]
    for t in text.split(' '):
        try:
            l.append(float(t))
        except ValueError:
            pass
    return (l)
def add(a,b):
    print("Lovely,This is your result",(a+b)) 
def sub(a,b):
    if(a>b):
        print("Lovely,This is your result",(a-b))
    else:
        print("Lovely, This is your result",(b-a))
def multiply(a,b):
    print("Lovely,This is your result",(a*b))
def division(a,b):
    if(a>b):
        print("Lovely,This is your result",(a/b))
    else:
        print("Lovely,This is your result",(b/a))
        
def lcm(a,b):
    L=a if a>b else b
    while L<=a*b:
        if L%a==0 and L%b==0:
            print("Lovely,This is your result",L)
            break
        L+=1
def hcf(a,b):
    h=a if a<b else b
    while h>=1:
        if a%h==0 and b%h==0:
            print("Lovely,This is your result",h)
            break
        h-=1
def end():
    print(responses[2])
    input("OOW!,Enter any key to exit")
    exit()
def sorry():
    print(responses[3])
def myName():
    print(responses[1])
def hi():
    print(responses[5])
def hlp():
    print("Yes,tell me",responses[4])
def thank():
    print(responses[6])

operations={"PLUS":add,"ADD":add,"ADDITION":add,"SUM":add,"MINUS":sub,"SUBTRACTION":sub,"SUBTRACT":sub,"DIFFERENCE":sub,
           "SHORTER":sub,"GREATER":sub,"TIMES":multiply,"MULTIPLICATION":multiply,"PRODUCT":multiply,
           "MULTIPLY":multiply,"DIVIDE":division,"DIVISION":division,"LCM":lcm,"HCF":hcf}
commands={"NAME":myName,"HI":hi,"HEY":hi,"HLW":hi,"END":end,"EXIT":end,"CLOSE":end,"HELP":hlp,"THANKS":thank,"THANK,YOU":thank}
print(responses[0])
print(responses[1])
print(responses[4])
while True:     #infinite loop
    text=input("Enter some text :")
    for word in text.split(' '):
        if word.upper() in operations.keys():
            try:
                l=extract_number_from_text(text)
                operations[word.upper()](l[0],l[1])
            except:
                print("OOPS,Something went wrong please retry")
            finally:
                break
        elif word.upper() in commands.keys():
            commands[word.upper()]()
            break
else:
    sorry()
# Out:
# Welcome user
# My name is smarty
# How can i help you in normal mathematcal calculation
# Enter some text :hey
# Hlw
# Enter some text :what is your name
# My name is smarty
# Enter some text :smarty can you please add 8554 and 8456
# Lovely,This is your result 17010.0
# Enter some text :thanks
# Mentoned not its my work
# Enter some text :find out the subtraction of 45 and 87
# Lovely, This is your result 42.0
# Enter some text :thank,you
# Mentoned not its my work
# Enter some text :i want to calculate the division of 8 by 5
# Lovely,This is your result 1.6
# Enter some text :what is the result of multiplication between 54 and 4
# Lovely,This is your result 216.0
# Enter some text :lcm of 7 and 9
# Lovely,This is your result 63.0
# Enter some text :hcf of 8 and 3
# Lovely,This is your result 1.0
# Enter some text :thanks
# Mentoned not its my work
# Enter some text :end
# Thanks
# OOW!,Enter any key to exitj
